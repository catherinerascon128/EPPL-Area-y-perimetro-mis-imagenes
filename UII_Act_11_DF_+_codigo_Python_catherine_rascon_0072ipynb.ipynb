# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinerascon128/EPPL-Area-y-perimetro-mis-imagenes/blob/main/UII_Act_11_DF_%2B_codigo_Python_catherine_rascon_0072ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### catherine rascon NL = 26 Fecha 25/Mar/26 ⚗
# ---
# # calcular Area de un triangulo ⚛
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/catherinerascon128/EPPL-Area-y-perimetro-mis-imagenes-/refs/heads/main/area%20de%20un%20triangulo.png)
#
# ---
# ## Formula para calcular el area
# $A = B*h/2$
# ## Datos de entrada
# $B,h?$
# ---
# ## diagrama de flujo en lucidchat
# ![Logo de Markdown](https://raw.githubusercontent.com/catherinerascon128/EPPL-Area-y-perimetro-mis-imagenes-/refs/heads/main/DF%20area%20de%20un%20triangulo.png)

# %%
# calcular area de un triangulo
# variebles B,h
# Formula A = B * h/2
B = float(input("ingrese la base del triangulo: "))
h = float(input("ingrese la altura del triangulo: "))
A = B * h/2
print("el area del triangulo es", A)
print("programa realizado por catherine rascon NL = 26")
# Out:
# ingrese la base del triangulo: 6
# ingrese la altura del triangulo: 8
# el area del triangulo es 24.0
# programa realizado por catherine rascon NL = 26

# %% [markdown]
# # Relacion entre el codigo y diagrama de flujo TLdraw
#
#
# ---
#
#
# ![Logo de Markdown](https://raw.githubusercontent.com/catherinerascon128/EPPL-Area-y-perimetro-mis-imagenes-/refs/heads/main/TL%20draw%20DF%20y%20codigo%202.png)
